# %%
from os import getcwd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from fish_simulator.simulator import (
    run,
    plot_skeletal_postures_with_trace,
    plot_tail_image_with_trace
)

PLOT_URL = ("https://gist.githubusercontent.com/"
       "ThomasMullen/e4a6a0abd54ba430adc4ffb8b8675520/"
       "raw/1189fbee1d3335284ec5cd7b5d071c3da49ad0f4/"
       "figure_style.mplstyle")
plt.style.use(PLOT_URL)

# %%
# load tail angle data
data_name = "swim01"
data_arr = np.load(Path(Path(getcwd()).parent, "test", "fixtures", f"{data_name}.npy"))

# plot tail angle data
fig, ax = plt.subplots(figsize=(3.5,3.5), dpi=300)
ax.plot(data_arr)
ax.set(xlabel="Time (frames)", 
       ylabel="Tail angle (Radians)",
       title="Tail trace")
fig.tight_layout()

# %%
# define a directory to save the plots and video
fig_dir = Path(Path(getcwd()).parent, "dump", "plts")


# Plot the posture on an animated fish structure
run(
    data_arr,
    plot_func=plot_skeletal_postures_with_trace,
    dir=f"{fig_dir}",
    vid_fp=f"{fig_dir.parent}/run_ani_{data_name}.mp4",
    n_intp_segs=30,
    line_wid=1,
)
# Out:
# onset 0
# 100%|██████████| 160/160 [01:01<00:00,  2.62it/s]
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, image2, from '/Users/thomasmullen/VSCodeProjects/fish_simulator/dump/plts/%05d.png':
#   Duration: 00:00:04.57, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 2800x1400 [SAR 13780:13780 DAR 2:1], 35 fps, 35 tbr, 35 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fb62772f400] using SAR=1/1
# [libx264 @ 0x7fb62772f400] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fb62772f400] profile High, level 5.0, 4:2:0, 8-bit
# [libx264 @ 0x7fb62772f400] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=24 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/thomasmullen/VSCodeProjects/fish_simulator/dump/run_ani_swim01.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 2800x1400 [SAR 1:1 DAR 2:1], q=2-31, 35 fps, 17920 tbn
#       Metadata:
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x7fb62772e940] video:231KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.047417%
# frame=  160 fps= 78 q=-1.0 Lsize=     233KiB time=00:00:04.51 bitrate= 423.3kbits/s speed= 2.2x
# [libx264 @ 0x7fb62772f400] frame I:1     Avg QP:13.57  size:  9032
# [libx264 @ 0x7fb62772f400] frame P:81    Avg QP:22.24  size:  2039
# [libx264 @ 0x7fb62772f400] frame B:78    Avg QP:25.52  size:   789
# [libx264 @ 0x7fb62772f400] consecutive B-frames: 30.0% 12.5%  7.5% 50.0%
# [libx264 @ 0x7fb62772f400] mb I  I16..4: 13.5% 84.6%  1.9%
# [libx264 @ 0x7fb62772f400] mb P  I16..4:  0.1%  0.2%  0.1%  P16..4:  0.6%  0.4%  0.3%  0.0%  0.0%    skip:98.3%
# [libx264 @ 0x7fb62772f400] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.8%  0.3%  0.1%  direct: 0.0%  skip:98.8%  L0:45.7% L1:40.6% BI:13.7%
# [libx264 @ 0x7fb62772f400] 8x8 transform intra:73.5% inter:31.4%
# [libx264 @ 0x7fb62772f400] coded y,uvDC,uvAC intra: 8.9% 0.0% 0.0% inter: 0.2% 0.0% 0.0%
# [libx264 @ 0x7fb62772f400] i16 v,h,dc,p: 67% 26%  7%  0%
# [libx264 @ 0x7fb62772f400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 12% 46%  0%  0%  0%  0%  0%  1%
# [libx264 @ 0x7fb62772f400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 30% 32%  6%  2%  2%  3%  3%  9%
# [libx264 @ 0x7fb62772f400] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x7fb62772f400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fb62772f400] ref P L0: 78.1%  4.2% 11.9%  5.8%
# [libx264 @ 0x7fb62772f400] ref B L0: 77.5% 18.7%  3.8%
# [libx264 @ 0x7fb62772f400] ref B L1: 94.0%  6.0%
# [libx264 @ 0x7fb62772f400] kb/s:412.48
# Saving video to: /Users/thomasmullen/VSCodeProjects/fish_simulator/dump/run_ani_swim01.mp4

# %% [markdown]
# <video src="https://github.com/ThomasMullen/fish_simulator/fish_simulator/examples/demo_vid/run_ani_swim01.mp4" width="640" height="480" controls>
# Your browser does not support the video tag.
# </video>

# %%
# define a directory to save the plots and video
fig_dir = Path(Path(getcwd()).parent, "dump", "plts")

run(
    data_arr,
    plot_func=plot_tail_image_with_trace,
    # plot_func=plot_tail_image,
    dir=f"{fig_dir}",
    vid_fp=f"{fig_dir.parent}/run_img_{data_name}.mp4",
    n_intp_segs=40,
    img_kwargs={"body_to_tail_mm": 156.3, "tail_to_tail_mm": -181.3},
    line_wid=1,
)
# Out:
# onset 171
# Entered plot_tail_image
# 100%|██████████| 160/160 [02:05<00:00,  1.27it/s]
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, image2, from '/Users/thomasmullen/VSCodeProjects/fish_simulator/dump/plts/%05d.png':
#   Duration: 00:00:04.57, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1200x600 [SAR 5906:5906 DAR 2:1], 35 fps, 35 tbr, 35 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x7fe2f6807d40] using SAR=1/1
# [libx264 @ 0x7fe2f6807d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x7fe2f6807d40] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x7fe2f6807d40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=19 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=25.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/thomasmullen/VSCodeProjects/fish_simulator/dump/run_img_swim01.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1200x600 [SAR 1:1 DAR 2:1], q=2-31, 35 fps, 17920 tbn
#       Metadata:
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   37 fps=0.0 q=32.0 size=       0KiB time=00:00:01.00 bitrate=   0.4kbits/s speed=1.98x
# Saving video to: /Users/thomasmullen/VSCodeProjects/fish_simulator/dump/run_img_swim01.mp4
# [out#0/mp4 @ 0x7fe2f6806f40] video:37KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 6.941608%
# frame=  160 fps=0.0 q=-1.0 Lsize=      40KiB time=00:00:04.51 bitrate=  72.4kbits/s speed=6.16x
# [libx264 @ 0x7fe2f6807d40] frame I:1     Avg QP:17.18  size:  2422
# [libx264 @ 0x7fe2f6807d40] frame P:58    Avg QP:22.12  size:   382
# [libx264 @ 0x7fe2f6807d40] frame B:101   Avg QP:22.27  size:   128
# [libx264 @ 0x7fe2f6807d40] consecutive B-frames: 10.0% 11.2% 18.8% 60.0%
# [libx264 @ 0x7fe2f6807d40] mb I  I16..4:  6.2% 92.2%  1.6%
# [libx264 @ 0x7fe2f6807d40] mb P  I16..4:  0.1%  0.2%  0.1%  P16..4:  1.1%  0.4%  0.2%  0.0%  0.0%    skip:97.9%
# [libx264 @ 0x7fe2f6807d40] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.2%  0.2%  0.0%  direct: 0.0%  skip:98.5%  L0:50.6% L1:43.5% BI: 6.0%
# [libx264 @ 0x7fe2f6807d40] 8x8 transform intra:82.2% inter:48.8%
# [libx264 @ 0x7fe2f6807d40] coded y,uvDC,uvAC intra: 7.2% 0.0% 0.0% inter: 0.1% 0.0% 0.0%
# [libx264 @ 0x7fe2f6807d40] i16 v,h,dc,p: 64% 13% 23%  0%
# [libx264 @ 0x7fe2f6807d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 62%  3% 33%  1%  0%  0%  0%  1%  1%
# [libx264 @ 0x7fe2f6807d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 18% 33%  5%  4%  7%  5%  4%  5%
# [libx264 @ 0x7fe2f6807d40] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x7fe2f6807d40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x7fe2f6807d40] ref P L0: 83.5%  5.4%  8.2%  3.0%
# [libx264 @ 0x7fe2f6807d40] ref B L0: 76.5% 19.4%  4.1%
# [libx264 @ 0x7fe2f6807d40] ref B L1: 97.2%  2.8%
# [libx264 @ 0x7fe2f6807d40] kb/s:65.62

# %% [markdown]
# <video src="https://github.com/ThomasMullen/fish_simulator/fish_simulator/examples/demo_vid/run_img_swim01.mp4" width="640" height="480" controls>
# Your browser does not support the video tag.
# </video>
